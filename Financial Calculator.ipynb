# %%
## By https://github.com/SaiRav95 ####

import math

# %run SairamMortgage.py
# %run SairamRisks.py
# %run SairamBonds.py
# %run SairamDerivatives.py
# %run SairamBasicInvestments.py

print('Welcome to the Financial Calculator designed by Sairam Ravuri.')
print('Please check the libraries before proceeding.')
print('Enter 1 for the value of key1 for Motgage calculations.')
print('Enter 2 for the value of key1 for Risk calculations. These are mostly some Credit Risk calculations.')
print('Enter 3 for the value of key1 for Bonds calculations.')
print('Enter 4 for the value of key1 for Derivatives calculations. These are Option Greeks and some Forward/Futures formulas.')
print('Enter 5 for the value of key1 for Basic Investment calculations.')
print('Enter any other value for key1 to exit the calculator.')
print('----------------------------------------------------------------------------------------------------------------')

key1 = int(input('Enter a number for the value of key1: '))
print('----------------------------------------------------------------------------------------------------------------')

if key1 == 1:
    print('You have chosen Mortgage Calculations.')
    print('This calculator provides the following calculations related to Mortgages:')
    print('1. Fixed Mortgage(P, r, n): This provides the monthly amount to be given to the lender to clear your debt. P is the')
    print('Outstanding loan amount, r is the annual interest rate and n is the total number of months.')
    print('----')
    print('2. AmountAtEachTime(P, r, n, t): This provides the amount still left on the principal at month t.')
    print('---')
    print('3. AdjustableRateMortgage(P, r): This is a 5/1 ARM which has a maturity of 30 years. The interest rates are random')
    print('which change fromr - 0.002 to r + 0.003. The output is a list which contains the remaining princiapal to be paid')
    print('every month.')
    print('---')
    print('4. InterestOnlyMortgage(P, r, n, x, k): It gives an output which 1 is Interest + Fixed and another only which is')
    print('Fixed. So, that you can verify which one is better. x is the number of years Interest only payments. k is the')
    print('extra amount paid during the interest only payments and will be reduced from the Pricipal when the Fixed Mortgage')
    print('Starts.')
    print('---')
    print('5. BalloonMortgage(P, r, n): Will be outputing the Monthly payments and the balloon amount in the last month')
    print('assuming 0.25% amount will be deducted from the principal every month')
    print('---')
    print('6. PriceLeveledAdjustedMortgage(P, r, n): Also called as PLAM. This takes inflation rates random from (-0.1, 0.4)')
    print('and it gives the output which inflation rates were chosen, Remaining principal every month and Amortization every')
    print('month as it changes with inflation rates')
    print('---')
    print('7. SingleMortalityRate(P1, P2, AP, SP): Also called as SMM. P1 is the amount of Principal left on month i. P2 is') 
    print('the amount of Principal left on month i + 1. AP is the amount paid on month i + 1. SP is the Scheduled Payment which')
    print('has to be paid on the month i + 1.')
    print('---')
    print('8. ConditionalPrepaymentRate(SMM): Gives the output of CPR1, CPR3 and CPR 6.')
    print('---')
    print('9. PSA(a, t): Gives PSAa where a can be 100, 150 etc and t is the number of months.')
    print('---')
    print('Please enter the following input values.')
    print('If the definition you require does not require a certain variable keep 0 for it.')
    print('---')
    P = float(input('P: Enter the Principal Amount: '))
    r = float(input('r: Enter the interest rate: '))
    n = int(input('n: Enter the total number of months: '))
    t = int(input('t: Enter the month required to find the remaining amount on principal or the number of months for PSA: '))
    x = int(input('x: Enter the number of months only interest: '))
    k = float(input('k: Enter the Principal Amount cleared in only Interest years: '))
    P1 = float(input('P1: Enter the Principal Amount left on the month i: '))
    P2 = float(input('P2: Enter the Principal Amount left on the month i + 1: '))
    AP = float(input('AP: Enter the Principal Amount paid on the month i + 1: '))
    SP = float(input('SP: Enter the Scheduled Principal Amount to be paid on the month i + 1: '))
    SMM = float(input('SMM: Enter the SMM value in percentage: '))
    a = int(input('a: Enter the number next to PSA: '))
    print('---')
    print('Enter the definition number you want to compute in the value of key2')
    print('---')
    key2 = int(input('Enter a number for the value of key2: '))
    print('---')
    
    if key2 == 1:
        print(FixedMortgage(P, r, n))
        
    elif key2 == 2:
        print(AmountAtEachTime(P, r, n, t))
        
    elif key2 == 3:
        print(AdjustableRateMortgage(P, r))
        
    elif key2 == 4:
        print(InterestOnlyMortgage(P, r, n, x, k))
        
    elif key2 == 5:
        print(BalloonMortgage(P, r, n))
        
    elif key2 == 6:
        print(PriceLeveledAdjustedMortgage(P, r, n))
        
    elif key2 == 7:
        print(SingleMortalityRate(P1, P2, AP, SP))
        
    elif key2 == 8:
        print(ConditionalPrepaymentRate(SMM))
        
    elif key2 == 9:
        print(PSA(a, t))     
        
    else:
        print('Error in input of key2')
        
        
elif key1 == 2:
    print('You have chosen Risk Calculations.')
    print('This calculator provides the following calculations related to mostly Credit Risk:')
    print('1. ExpectedLoss(PD, EA, LR): Computes the Expected loss of a firm. PD is the probability of default. EA is the')
    print('Exposure amount. LR is the loss rate')
    print('---')
    print('2. UnexpectedLoss(EA, PD, LR, stdLR): Computes the Unexpected loss of a firm. stdLR is the standard deviation of the')
    print('Loss Rate')
    print('---')
    print('3. RecoveryRate(LR): Computes the recovery rate of the firm.')
    print('---')
    print('4. PortfolioExpectedLoss(PD1, EA1, LR1, PD2, EA2, LR2): Computes the Expected loss of the Portfolio of 2 assets.')
    print('---')
    print('5. PortfolioUnexpectedLoss(EA1, PD1, LR1, stdLR1, EA2, PD2, LR2, stdLR2, rho): computes the Unexpected loss of the')
    print('portfolio of 2 assets where rho is the correlation between the two assets')
    print('---')
    print('6. RiskContribution(EA1, PD1, LR1, stdLR1, EA2, PD2, LR2, stdLR2, rho): Computes the risk contribution of each')
    print('asset. In this you have to enter 1 or 2 for the risk contribution of the first asset or second asset.')
    print('---')
    print('7. FirmSizeScaleAdjustement(Xr, Yl, Yr): This is a computation when you want to see your scale of severity')
    print('by viewing data from others banks. Xr is the Bank X revenue. Yl is the Bank Y loss from that event. Yr is')
    print('the Bank Y revenue. This will calculate the Bank X loss from that event by readjusting the scale.')
    print('---')
    print('8. ValueAtRisk(V, alpha, mu, sigma): Calculates Value At Risk of the firm with portfolio size V, mean mu, volatility')
    print('sigma and significance level alpha')
    print('9. LognormalValueAtRisk(V, alpha, mu, sigma): Calculates the LognormalVaR of the firm')
    print('---')
    print('10. ExpectedShortFall(V, alpha, mu, sigma): Calculates the Expected Shortfall of the firm')
    print('---')
    print('Please enter the following input values.')
    print('If the definition you require does not require a certain variable keep 0 for it.')
    print('---')
    PD = float(input('PD: Enter the Probability of default: '))
    EA = float(input('EA: Enter the Exposure Amount: '))
    LR = float(input('LR: Enter the Loss Rate: '))
    stdLR = float(input('stdLR: Enter the standard deviation for the loss rate (decimal): '))
    PD1 = float(input('PD1: Probability of default of asset 1: '))
    EA1 = float(input('EA1: Exposure amount of asset 1: '))
    LR1 = float(input('LR1: Loss Rate of asset 1: '))
    PD2 = float(input('PD2: Probability of default of asset 2: '))
    EA2 = float(input('EA2: Exposure amount of asset 2: '))
    LR2 = float(input('LR2: Loss Rate of asset 2: '))
    stdLR1 = float(input('stdLR1: standard deviation of the loss rate for asset 1: '))
    stdLR2 = float(input('stdLR2: standard deviation of the loss rate for asset 2: '))
    rho = float(input('rho: correlation between the two assets: '))
    Xr = float(input('Xr: Bank X revenue: '))
    Yl = float(input('Yl: Bank Y loss from that event which you are trying to scale: '))
    Yr = float(input('Yr: Bank Y revenue: '))
    V = float(input('V: Portfolio Value: '))
    alpha = float(input('alpha: Significance level: '))
    mu = float(input('mu: Expected Mean Return: '))
    sigma = float(input('sigma: Volatility this is for VaR computation: '))
    print('---')
    print('Enter the definition number you want to compute in the value of key2')
    print('---')
    key2 = int(input('Enter a number for the value of key2: '))
    print('---')
    
    if key2 == 1:
        print(ExpectedLoss(PD, EA, LR))
        
    elif key2 == 2:
        print(UnexpectedLoss(EA, PD, LR, stdLR))
        
    elif key2 == 3:
        print(RecoveryRate(LR))
        
    elif key2 == 4:
        print(PortfolioExpectedLoss(PD1, EA1, LR1, PD2, EA2, LR2))
        
    elif key2 == 5:
        print(PortfolioUnexpectedLoss(EA1, PD1, LR1, stdLR1, EA2, PD2, LR2, stdLR2, rho))
        
    elif key2 == 6:
        print(RiskContribution(EA1, PD1, LR1, stdLR1, EA2, PD2, LR2, stdLR2, rho))
        
    elif key2 == 7:
        print(FirmSizeScaleAdjustement(Xr, Yl, Yr))
        
    elif key2 == 8:
        print(ValueAtRisk(V, alpha, mu, sigma))
        
    elif key2 == 9:
        print(LognormalValueAtRisk(V, alpha, mu, sigma))
    
    elif key2 == 10:
        print(ExpectedShortFall(V, alpha, mu, sigma))
        
    else:
        print('Error in input of key2')
        
        
elif key1 == 3:
    print('You have chosen Bond Calculations.')
    print('This calculator provides the following calculations related to Bond pricing, duration and convexity mostly:')
    print('1. BondPrice(F, c, y, T, frequency): Computes the Price of the bond.  F is the face value of the bond. c is the')
    print('coupon rate. y is the YTM. T is the time to maturity (T> 1 here). frequency is the number of coupon payments a year')
    print('---')
    print('2. ZeroCouponBondPrice(F, y, t): Price of a zero coupon bond')
    print('---')
    print('3. AccruedInterest(c, x, y). Computes the accured Interest of the bond where x is the number of days from last')
    print('coupon to the settlement date. y is the total number of days in the coupon period')
    print('---')
    print('4. DirtyPrice(c, y, n, F, x, l): c is the semi annual coupon payment. y is the yield (decimal) (convert to the')
    print('required one when given annual). w (see library) is the x/l in the Accured Interest')
    print('---')
    print('5. CleanPrice(c, y, n, F, x, l): Computes clean price of the bond.')
    print('---')
    print('6. HoldingPeriodReturn(FV, PV, m, n): Holding period return.')
    print('---')
    print('7. SpotRate(d, t): Spot rate given the discount factor d(t) at time t.')
    print('---')
    print('8. ForwardRate(r1, r2, T1, T2): Interest rate r1, r2 at times T1 and T2')
    print('---')
    print('9. Duration(B1, B2, y1, y2): Bond price B1, B2 for yield y1 and y2')
    print('---')
    print('10. ModifiedDuration(B1, B2, y1, y2, m): m is the number of times it is compounded per year.')
    print('---')
    print('11. DollarDuration(B1, B2, y1, y2, m)')
    print('---')
    print('12. EffectiveDuration(F, c, y, T, frequency, dy): dy is just yield differential (a very small value just an)')
    print('increment or decrement.')
    print('---')
    print('13. Convexity(F, c, y, T, frequency, dy):')
    print('---')
    print('14. BondPercentageChange(F, c, y, T, frequency, dy):')
    print('---')
    print('15. DV01(F, c, y, T, frequency, dy):')
    print('---')
    print('16. GrossRealizedReturns(P, F, c)')
    print('---')
    print('17. NetRealizedReturns(P, F, c, r, n):')
    print('---')
    print('Please enter the following input values.')
    print('If the definition you require does not require a certain variable keep 0 for it.')
    print('---')
    F = float(input('F: Face value of the bond: '))
    c = float(input('c: coupon rate: '))
    T = float(input('T: Time to Maturity (T > 1): '))
    frequency = int(input('frequency: number of coupon payments a year: '))
    t = float(input('t: Time to maturity for the zero coupon bond or the t for the d(t) in spot rate: '))
    x = int(input('x: number of days from last coupon to the settlement date: '))
    y = float(input('y: YTM (decimal) or total number of days in the coupon period (integer): '))
    l = int(input('l: it is the y for accured interest: '))
    FV = float(input('FV: Future Value: '))
    PV = float(input('PV: Present Value: '))
    n = int(input('n: number of years: '))
    d = float(input('d: discount rate d(t) at time t: '))
    r1 = float(input('r1: continously compounded Interest rate r1 at time T1: '))
    T1 = float(input('Tl: Time period T1: '))
    r2 = float(input('r2: continously compounded Interest rate r2 at time T2: '))
    T2 = float(input('T2: Time period T2: '))
    B1 = float(input('B1: Bond Price B1 for yield y1: '))
    y1 = float(input('yl: yield y1: '))
    B2 = float(input('B2: Bond Price B2 for yield y2: '))
    y2 = float(input('y2: yield y2: '))    
    m = float(input('m: Number of times compounded per year: '))
    dy = float(input('dy: differential in yield price: '))
    r = float(input('r: the annual rate at which the borrowing was made to buy the bond: '))
    P = float(input('P: Present value of the bond: '))
    print('---')
    print('Enter the definition number you want to compute in the value of key2')
    print('---')
    key2 = int(input('Enter a number for the value of key2: '))    
    print('---')
    
    if key2 == 1:
        print(BondPrice(F, c, y, T, frequency))
        
    elif key2 == 2:
        print(ZeroCouponBondPrice(F, y, t))
        
    elif key2 == 3:
        print(AccruedInterest(c, x, y))
        
    elif key2 == 4:
        print(DirtyPrice(c, y, n, F, x, l))
        
    elif key2 == 5:
        print(CleanPrice(c, y, n, F, x, l))
        
    elif key2 == 6:
        print(HoldingPeriodReturn(FV, PV, m, n))
        
    elif key2 == 7:
        print(SpotRate(d, t))
        
    elif key2 == 8:
        print(ForwardRate(r1, r2, T1, T2))
        
    elif key2 == 9:
        print(Duration(B1, B2, y1, y2))
    
    elif key2 == 10:
        print(ModifiedDuration(B1, B2, y1, y2, m))
        
    elif key2 == 11:
        print(DollarDuration(B1, B2, y1, y2, m))
        
    elif key2 == 12:
        print(EffectiveDuration(F, c, y, T, frequency, dy))
        
    elif key2 == 13:
        print(Convexity(F, c, y, T, frequency, dy))
        
    elif key2 == 14:
        print(BondPercentageChange(F, c, y, T, frequency, dy))
        
    elif key2 == 15:
        print(DV01(F, c, y, T, frequency, dy))
        
    elif key2 == 16:
        print(GrossRealizedReturns(P, F, c))
        
    elif key2 == 17:
        print(NetRealizedReturns(P, F, c, r, n))
        
    else:
        print('Error in input of key2')    
        
elif key1 == 4:
    print('You have chosen Derivative Calculations.')
    print('This calculator provides the calculations related to Option Greeks and some Forward/Futures formulas:')
    print('1. DeltaCallOption(S, K, r, q, sigma, T): Computes the Delta value of a Call option. S is asset price.')
    print('K is the strike price, r is the interest rate, q is the dividend rate for options and also foreign interest rate.')
    print('---')
    print('2. DeltaPutOption(S, K, r, q, sigma, T): Delta value of a Put Option.')
    print('---')
    print('3. CallOption(S, K, r, q, sigma, T): Price of a Call Option.')
    print('---')
    print('4. PutOption(S, K, r, q, sigma, T): Price of a Call Option.')
    print('---')
    print('5. ForwardDelta(q, T): Delta of a Forward Position.')
    print('---')
    print('6. FuturesDelta(r, q, T): Delta of a Futures Position.')
    print('---')
    print('7. ThetaCall(S, K, r, q, sigma, T): Theta value of a Call Option')
    print('---')
    print('8. ThetaPut(S, K, r, q, sigma, T): Theta value of a Put Option')
    print('---')
    print('9. GammaEuro(S, K, r, q, sigma, T): Gamma value of a European Option')
    print('---')
    print('10. VegaEuro(S, K, r, q, sigma, T): Vega value of a European Option')
    print('---')
    print('11. RhoCall(S, K, r, q, sigma, T): Rho value of a Call Option')
    print('---')
    print('12. RhoPut(S, K, r, q, sigma, T): Rho value of a Put Option')
    print('---')
    print('13. ForwardPrice(S, r, q, t): Price of the Forward positon where r is continously compounded interest rate.')
    print('---')
    print('14. ForwardPriceCarryingCost(S, r, q, t, I): Price of the Forward positon where I is carrying cost.')
    print('---')
    print('15. ForwardPriceConvenienceYield(S, r, q, t, u, y): Price of the Forward positon where u is storage cost.')
    print('and y is the convenience yield')
    print('---') 
    print('Please enter the following input values.')
    print('If the definition you require does not require a certain variable keep 0 for it.')
    print('---')
    S = float(input('S: Asset value: '))
    K = float(input('K: Strike Price: '))
    r = float(input('r: interest rate and continously compounded for Forward formulas: '))
    q = float(input('q: dividend rate: '))
    sigma = float(input('sigma: Volatility of the asset price.: '))
    T = float(input('T: Time to maturity of the Option.: '))
    t = float(input('t: Time to maturity of the Forward position.: '))
    I = float(input('I: Carrying cost of the Forward Position.: '))
    u = float(input('u: Storage cost of the Forward Position.: '))
    y = float(input('y: Convenience yield of the Forward Position.: '))
    print('---')
    print('Enter the definition number you want to compute in the value of key2')
    print('---')
    key2 = int(input('Enter a number for the value of key2: '))    
    print('---')
    
    if key2 == 1:
        print(DeltaCallOption(S, K, r, q, sigma, T))
        
    elif key2 == 2:
        print(DeltaPutOption(S, K, r, q, sigma, T))
        
    elif key2 == 3:
        print(CallOption(S, K, r, q, sigma, T))
        
    elif key2 == 4:
        print(PutOption(S, K, r, q, sigma, T))
        
    elif key2 == 5:
        print(ForwardDelta(q, T))
        
    elif key2 == 6:
        print(FuturesDelta(r, q, T))
        
    elif key2 == 7:
        print(ThetaCall(S, K, r, q, sigma, T))
        
    elif key2 == 8:
        print(ThetaPut(S, K, r, q, sigma, T))
        
    elif key2 == 9:
        print(GammaEuro(S, K, r, q, sigma, T))
    
    elif key2 == 10:
        print(VegaEuro(S, K, r, q, sigma, T))
        
    elif key2 == 11:
        print(RhoCall(S, K, r, q, sigma, T))  
        
    elif key2 == 12:
        print(RhoPut(S, K, r, q, sigma, T))
        
    elif key2 == 13:
        print(ForwardPrice(S, r, q, t))
        
    elif key2 == 14:
        print(ForwardPriceCarryingCost(S, r, q, t, I))
        
    elif key2 == 15:
        print(ForwardPriceConvenienceYield(S, r, q, t, u, y)) 
        
    else:
        print('Error in input of key2')  
        
elif key1 == 5:
    print('You have chosen Basic Investment Calculations.')
    print('This calculator provides the following calculations related to mostly simple interest rate calculations:')
    print('1. SimpleInterest(PV, r, t): Computes Simple Interest.')
    print('---')
    print('2. Compoundinterest(PV, r, n, t): Computes Compund Interest where n is the number of times compunded.')
    print('---')
    print('3. ContinouoslyCompounded(PV, r, n): Computes Continously Compounded Interest.')
    print('---')
    print('4. EffectiveInterestRate(r, m): Computes Effective interest rate where m is the number of times compounded.')
    print('---')
    print('5. Annuity(c, y, n): Computes Annuity where n is the number of payments')
    print('---')
    print('6. Perpetuity(c, y): Computes Perpetuity.')
    print('---')
    print('Please enter the following input values.')
    print('If the definition you require does not require a certain variable keep 0 for it.')
    print('---')    
    PV = float(input('PV: Present Value: '))
    FV = float(input('FV: Future Value: '))
    r = float(input('r: interest rate: '))
    n = int(input('n: number of years or number of times compounded or number of payments depends on the formula definition: '))
    m = int(input('m: number of times compounded: '))
    y = float(input('y: YTM (decimal): '))
    c = float(input('c: Fixed payment received each time when payment is needed: '))
    t = int(input('t: Number of years: ')) 
    print('---')
    print('Enter the definition number you want to compute in the value of key2')
    print('---')
    key2 = int(input('Enter a number for the value of key2: '))    
    print('---')
    
    if key2 == 1:
        print(SimpleInterest(PV, r, t))
        
    elif key2 == 2:
        print(Compoundinterest(PV, r, n, t))
        
    elif key2 == 3:
        print(ContinouoslyCompounded(PV, r, n))
        
    elif key2 == 4:
        print(EffectiveInterestRate(r, m))
        
    elif key2 == 5:
        print(Annuity(c, y, n))
        
    elif key2 == 6:
        print(Perpetuity(c, y))
        
    else:
        print('Error in input of key2')
        
else:
    print('Bye')
